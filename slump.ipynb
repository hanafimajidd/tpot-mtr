# %%
from tpot import TPOTRegressor


import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-slump.csv')
df.head()
y_col = [
'SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa'

]
y = df[y_col]
#x_col_id = ['id']
#x_id = df[x_col_id]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
#X = df[df.columns.drop(y)]
#X=df.drop(columns=['id'])
X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()


X

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)

from sklearn.preprocessing import MinMaxScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler


from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor

rfg = MultiOutputRegressor(TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=1, max_time_mins=None, max_eval_time_mins=5, cv=10,scoring='neg_mean_squared_error'))
# Create a TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=rfg, transformer=target_transformer)
model.fit(X_train, y_train)

#rfg.fit(X_train, y_train)
#y_pred = rfg.predict(X_test)
#rfg.score(X_test, y_test)
y_pred=model.predict(X_test)
model.score(X_test, y_test)



import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse1=np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE  is',rmse1)
mae1=mean_absolute_error(y_test, y_pred)
print('MAE is',mae1)

# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    #rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred, multioutput='raw_values'))
    num = np.sum((np.square(true - pred)) / n)  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss

rrmse2=relative_root_mean_squared_error(y_test,y_pred)
arrmse2=mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("rrmse =",rrmse2)
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small=pd.DataFrame(y_pred)
#df_small = y_test.iloc[:,:3]
features=['SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa']
correlation_mat = df_small.corr('pearson')
sns.heatmap(correlation_mat, annot = True,yticklabels=features,xticklabels=features)
plt.show()
# Out:
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.06674450946273883
#
# Generation 2 - Current best internal CV score: -0.06437500241757978
#
# Generation 3 - Current best internal CV score: -0.06437500241757978
#
# Generation 4 - Current best internal CV score: -0.05277853550781205
#
# Generation 5 - Current best internal CV score: -0.05202415583684409
#
# Generation 6 - Current best internal CV score: -0.05202415583684409
#
# Generation 7 - Current best internal CV score: -0.04961176013850833
#
# Generation 8 - Current best internal CV score: -0.04495574018012146
#
# Generation 9 - Current best internal CV score: -0.04495574018012146
#
# Generation 10 - Current best internal CV score: -0.04495574018012146
#
# Best pipeline: RandomForestRegressor(RidgeCV(ExtraTreesRegressor(ZeroCount(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False)), bootstrap=False, max_features=0.5, min_samples_leaf=15, min_samples_split=6, n_estimators=100)), bootstrap=False, max_features=0.6500000000000001, min_samples_leaf=11, min_samples_split=17, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.055020131104073625
#
# Generation 2 - Current best internal CV score: -0.053928525414042014
#
# Generation 3 - Current best internal CV score: -0.05168361970576546
#
# Generation 4 - Current best internal CV score: -0.050253332201945555
#
# Generation 5 - Current best internal CV score: -0.04821203687859869
#
# Generation 6 - Current best internal CV score: -0.04796809878316764
#
# Generation 7 - Current best internal CV score: -0.04796809878316764
#
# Generation 8 - Current best internal CV score: -0.04796809878316764
#
# Generation 9 - Current best internal CV score: -0.04793163175241667
#
# Generation 10 - Current best internal CV score: -0.04786090536731285
#
# Best pipeline: RandomForestRegressor(GradientBoostingRegressor(Normalizer(input_matrix, norm=l1), alpha=0.95, learning_rate=0.01, loss=huber, max_depth=9, max_features=0.5, min_samples_leaf=2, min_samples_split=17, n_estimators=100, subsample=0.8), bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=3, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.004518091545033304
#
# Generation 2 - Current best internal CV score: -0.004518020388471463
#
# Generation 3 - Current best internal CV score: -0.0045178339960176925
#
# Generation 4 - Current best internal CV score: -0.0042565351834902895
#
# Generation 5 - Current best internal CV score: -0.0040186565390375835
#
# Generation 6 - Current best internal CV score: -0.0040186565390375835
#
# Generation 7 - Current best internal CV score: -0.002080217650725066
#
# Generation 8 - Current best internal CV score: -0.002080217650725066
#
# Generation 9 - Current best internal CV score: -0.0018641092971732973
#
# Generation 10 - Current best internal CV score: -0.0004431499949512437
#
# Best pipeline: RidgeCV(ExtraTreesRegressor(LinearSVR(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), C=0.5, dual=False, epsilon=1.0, loss=squared_epsilon_insensitive, tol=1e-05), bootstrap=True, max_features=0.25, min_samples_leaf=4, min_samples_split=16, n_estimators=100))
# RMSE  is 7.643489371803626
# MAE is 4.528564786556961
# rmse_per_output: [ 5.19306732 12.16054285  0.64964511]
# rrmse = SLUMP_cm                    0.016932
# FLOW_cm                     0.039649
# Compressive_Strength_Mpa    0.002118
# dtype: float64
# arrmse = 0.01956624732501761
# Percentage arrmse = 1.96%
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
mean_corr = correlation_mat.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr}")
# Out:
# Mean absolute correlation - Dataset 1: 0.5466910690164977

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-slump.csv')
df.head()
y_col = [
'SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa'

]
y = df[y_col]
#x_col_id = ['id']
#x_id = df[x_col_id]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
#X = df[df.columns.drop(y)]
#X=df.drop(columns=['id'])
X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
X_train.head(10)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)

from sklearn.preprocessing import MinMaxScaler,StandardScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))
#scaler=StandardScaler()

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.multioutput import RegressorChain

#reg=LinearSVR(C=0.1, dual=False, fit_intercept=True, max_iter=1000,random_state=123,loss='squared_epsilon_insensitive')
reg=TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=1, max_time_mins=None, max_eval_time_mins=5, cv=10,scoring='neg_mean_squared_error')
chain = RegressorChain(base_estimator=reg, order=[0,1,2])
# Create a TransformedTargetRegressor
from sklearn.compose import TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=chain, transformer=target_transformer)
model.fit(X_train, y_train)
y_pred2 = model.predict(X_test)
model.score(X_test, y_test)

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse2=math.sqrt(mean_squared_error(y_test, y_pred2))
print('RMSE  is',rmse2)
mae2=mean_absolute_error(y_test, y_pred2)
print('MAE is',mae2)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse2=relative_root_mean_squared_error(y_test,y_pred2)
arrmse2=np.mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("rrmse =",rrmse2)
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small2=pd.DataFrame(y_pred2)
#df_small = y_test.iloc[:,:3]
features=['SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa']
correlation_mat2 = df_small2.corr('pearson')
sns.heatmap(correlation_mat2, annot = True,yticklabels=features,xticklabels=features)
plt.show()
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.06258673436924804
#
# Generation 2 - Current best internal CV score: -0.06258673436924804
#
# Generation 3 - Current best internal CV score: -0.06001099509076467
#
# Generation 4 - Current best internal CV score: -0.06001099509076467
#
# Generation 5 - Current best internal CV score: -0.06001099509076467
#
# Generation 6 - Current best internal CV score: -0.06001099509076467
#
# Generation 7 - Current best internal CV score: -0.06001099509076467
#
# Generation 8 - Current best internal CV score: -0.0598671765541544
#
# Generation 9 - Current best internal CV score: -0.058487264821306006
#
# Generation 10 - Current best internal CV score: -0.058487264821306006
#
# Best pipeline: RandomForestRegressor(ElasticNetCV(input_matrix, l1_ratio=0.6000000000000001, tol=0.01), bootstrap=False, max_features=0.2, min_samples_leaf=3, min_samples_split=2, n_estimators=100)
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.01037063484018079
#
# Generation 2 - Current best internal CV score: -0.01037063484018079
#
# Generation 3 - Current best internal CV score: -0.00990376913681094
#
# Generation 4 - Current best internal CV score: -0.009874967212898433
#
# Generation 5 - Current best internal CV score: -0.009872295440319551
#
# Generation 6 - Current best internal CV score: -0.009339203418678593
#
# Generation 7 - Current best internal CV score: -0.009061953822903843
#
# Generation 8 - Current best internal CV score: -0.009061953822903843
#
# Generation 9 - Current best internal CV score: -0.007438892174809293
#
# Generation 10 - Current best internal CV score: -0.00739735897595607
#
# Best pipeline: ElasticNetCV(RandomForestRegressor(RBFSampler(MinMaxScaler(CombineDFs(input_matrix, input_matrix)), gamma=0.1), bootstrap=False, max_features=0.9000000000000001, min_samples_leaf=18, min_samples_split=9, n_estimators=100), l1_ratio=1.0, tol=0.001)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.004419116510923309
#
# Generation 2 - Current best internal CV score: -0.004419116510923309
#
# Generation 3 - Current best internal CV score: -0.004396641132319448
#
# Generation 4 - Current best internal CV score: -0.0020802088939555863
#
# Generation 5 - Current best internal CV score: -0.000651112262288399
#
# Generation 6 - Current best internal CV score: -0.000651112262288399
#
# Generation 7 - Current best internal CV score: -0.00036369065150819815
#
# Generation 8 - Current best internal CV score: -0.00036369065150819815
#
# Generation 9 - Current best internal CV score: -0.00036369065150819815
#
# Generation 10 - Current best internal CV score: -0.00036369065150819815
#
# Best pipeline: RidgeCV(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False))
# RMSE  is 8.625085317702357
# MAE is 4.849670797613977
# rmse_per_output: [ 4.862474   14.11602318  0.52012167]
# rrmse = SLUMP_cm                    0.016022
# FLOW_cm                     0.046512
# Compressive_Strength_Mpa    0.001714
# dtype: float64
# arrmse = 0.021415836274056865
# Percentage arrmse = 2.14%
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
mean_corr2 = correlation_mat2.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr2}")
# Out:
# Mean absolute correlation - Dataset 1: 0.5930041521591612

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-slump.csv')
df.head()
y_col = [
'SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa'

]
y = df[y_col]
#x_col_id = ['id']
#x_id = df[x_col_id]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
#X = df[df.columns.drop(y)]
#X=df.drop(columns=['id'])
X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
X_train.head(10)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler,StandardScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

#scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
y_train=scaler.fit_transform(y_train)
y_test=scaler.fit_transform(y_test)

from sklearn.svm import LinearSVR
class MultiOutputTP(object):
  def __init__(self, *args, **kwargs):
    self.args = args
    self.kwargs = kwargs
  def fit(self, X, y):
    X, y = map(np.atleast_2d, (X, y))
    assert X.shape[0] == y.shape[0]
    yy = y.shape[1]
    self.regs = []
    for i in range(yy):
#while i <= Ny:
      reg = TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=1, max_time_mins=None, max_eval_time_mins=5, cv=10,scoring='neg_mean_squared_error')
      #reg = LinearSVR(epsilon=0.0, tol=0.0001, C=1.0, loss='epsilon_insensitive', fit_intercept=True, intercept_scaling=1.0, dual=True, verbose=1, random_state=123, max_iter=10000)
      Xi = np.hstack([X, y[:, :i]])
      yi = y[:, i]
      self.regs.append(reg.fit(Xi, yi))


    return self
  def predict(self, X):
    y = np.empty([X.shape[0], len(self.regs)])
    for i, reg in enumerate(self.regs):
      y[:, i] = reg.predict(np.hstack([X, y[:, :i]]))
    return y


import numpy as np
from tpot import decorators
#decorators.MAX_EVAL_SECS = 240
reg2 = MultiOutputTP(1).fit(X_train, y_train)
#X = np.dtype('float64')




Ypred2 = reg2.predict(X_test)

from sklearn.metrics import r2_score
r2 = np.abs(r2_score(y_test, Ypred2))
print('r2 score for perfect model is', r2)

y_test=scaler.inverse_transform(y_test)
Ypred2=scaler.inverse_transform(Ypred2)

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small3=pd.DataFrame(Ypred2)
#df_small = y_test.iloc[:,:3]
features=['SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa']
correlation_mat3 = df_small3.corr('pearson')
sns.heatmap(correlation_mat3, annot = True,yticklabels=features,xticklabels=features)
plt.show()

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse3=math.sqrt(mean_squared_error(y_test, Ypred2))
print('RMSE  is',rmse3)
mae3=mean_absolute_error(y_test, Ypred2)
print('MAE  is',mae3)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, Ypred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)

def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse3=relative_root_mean_squared_error(y_test,Ypred2)
arrmse3=np.mean(rrmse3)
percentage_average_relative_rmse3 = arrmse3 * 100
print("relative_root_mean_squared_error =", rrmse3)
print("arrmse =", arrmse3)
print(f"Percentage arrmse = {percentage_average_relative_rmse3:.2f}%")
# Out:
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.06185061781042719
#
# Generation 2 - Current best internal CV score: -0.06185061781042719
#
# Generation 3 - Current best internal CV score: -0.06042943132040126
#
# Generation 4 - Current best internal CV score: -0.06042943132040126
#
# Generation 5 - Current best internal CV score: -0.06042943132040126
#
# Generation 6 - Current best internal CV score: -0.05065939137502849
#
# Generation 7 - Current best internal CV score: -0.05065939137502849
#
# Generation 8 - Current best internal CV score: -0.050422397389866
#
# Generation 9 - Current best internal CV score: -0.048904508298563173
#
# Generation 10 - Current best internal CV score: -0.048904508298563173
#
# Best pipeline: ExtraTreesRegressor(RBFSampler(RidgeCV(input_matrix), gamma=0.55), bootstrap=False, max_features=0.8, min_samples_leaf=1, min_samples_split=15, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.00924718000006248
#
# Generation 2 - Current best internal CV score: -0.00924718000006248
#
# Generation 3 - Current best internal CV score: -0.00924718000006248
#
# Generation 4 - Current best internal CV score: -0.008228801223072325
#
# Generation 5 - Current best internal CV score: -0.008228801223072325
#
# Generation 6 - Current best internal CV score: -0.008228801223072325
#
# Generation 7 - Current best internal CV score: -0.008189536640762345
#
# Generation 8 - Current best internal CV score: -0.0077592821520533805
#
# Generation 9 - Current best internal CV score: -0.0077592821520533805
#
# Generation 10 - Current best internal CV score: -0.0077592821520533805
#
# Best pipeline: RidgeCV(RBFSampler(SelectPercentile(ElasticNetCV(RidgeCV(input_matrix), l1_ratio=0.25, tol=0.1), percentile=24), gamma=0.45))
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.004418441097506922
#
# Generation 2 - Current best internal CV score: -0.004418441097506922
#
# Generation 3 - Current best internal CV score: -0.004112715979794087
#
# Generation 4 - Current best internal CV score: -0.004079924432777158
#
# Generation 5 - Current best internal CV score: -0.0004907785790253073
#
# Generation 6 - Current best internal CV score: -0.0004907785790253073
#
# Generation 7 - Current best internal CV score: -0.0004907785790253073
#
# Generation 8 - Current best internal CV score: -0.0004907785790253073
#
# Generation 9 - Current best internal CV score: -0.0004907785790253073
#
# Generation 10 - Current best internal CV score: -0.0004907785790253073
#
# Best pipeline: ElasticNetCV(CombineDFs(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), input_matrix), l1_ratio=0.8500000000000001, tol=1e-05)
# r2 score for perfect model is 0.3202303138037615
# RMSE  is 8.249056857082532
# MAE  is 6.316924263634422
# rmse_per_output: [ 6.04924461 11.51611825  5.90986271]
# relative_root_mean_squared_error = 0.0508832873976682
# arrmse = 0.0508832873976682
# Percentage arrmse = 5.09%

# %%
mean_corr3 = correlation_mat3.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr3}")
# Out:
# Mean absolute correlation - Dataset 1: 0.5801702191847836

# %%
import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat2.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
features=['SLUMP_cm',
'FLOW_cm',
'Compressive_Strength_Mpa']
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs Chain_Reg-TPOT")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat2.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))

sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps Chain_Reg-TPOT vs TPOT-MTR")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs TPOT-MTR")
plt.show()



import numpy as np

def fisher_z_transform(corr_matrix):
    return np.arctanh(corr_matrix)  # Equivalent to the formula above

z_A = fisher_z_transform(correlation_mat)
z_B = fisher_z_transform(correlation_mat2)
z_C = fisher_z_transform(correlation_mat3)

from scipy.stats import norm

n1, n2 = len(X), len(X)  # Sample sizes
z_diff_AB = (z_A - z_B) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
p_values_AB = 2 * (1 - norm.cdf(np.abs(z_diff_AB)))

z_diff_BC = (z_B - z_C) / np.sqrt(1 / (n2 - 3) + 1 / (len(X) - 3))
p_values_BC = 2 * (1 - norm.cdf(np.abs(z_diff_BC)))

z_diff_AC = (z_A - z_C) / np.sqrt(1 / (n1 - 3) + 1 / (len(X) - 3))
p_values_AC = 2 * (1 - norm.cdf(np.abs(z_diff_AC)))


import seaborn as sns
import matplotlib.pyplot as plt



significant_diff = (p_values_AB < 0.05).astype(int)
sns.heatmap(significant_diff, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. Chain_Reg-TPOT)')
plt.show()

significant_diff2 = (p_values_BC < 0.05).astype(int)
sns.heatmap(significant_diff2, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (Chain_Reg-TPOT vs. TPOT-MTR)')
plt.show()

significant_diff3 = (p_values_AC < 0.05).astype(int)
sns.heatmap(significant_diff3, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. TPOT-MTR)')
plt.show()
# Out:
# [[       nan 0.14655229 0.3098059 ]
#  [0.14655229        nan 0.42244661]
#  [0.3098059  0.42244661        nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:6: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:18: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# [[       nan 0.00473975 0.36364938]
#  [0.00473975        nan 0.03079643]
#  [0.36364938 0.03079643        nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:43: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:55: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:78: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10052\911842441.py:90: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# [[           nan 1.90258756e-05 5.43467346e-02]
#  [1.90258756e-05            nan 1.74619423e-01]
#  [5.43467346e-02 1.74619423e-01            nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\blocks.py:393: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)
