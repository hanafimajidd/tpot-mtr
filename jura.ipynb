# %%
from tpot import TPOTRegressor
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-jura.csv')
df.head()
y_col = [
'Cd',
'Cu',
'Pb',
# 'Y4',
# 'Y5',
# 'Y6'
]
y = df[y_col]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
X = df[df.columns.drop(y)]
#X=df.drop(columns=['Cd','Cu','Pb'])
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler


X_train

y_train

import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor
#rfg = MultiOutputRegressor(RandomForestRegressor(n_estimators=100,criterion='squared_error'))
rfg = MultiOutputRegressor(TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10, scoring='neg_mean_squared_error'))
# Create a TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=rfg, transformer=target_transformer)
model = rfg.fit(X_train, y_train)
y_pred = model.predict(X_test)
model.score(X_test, y_test)

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse1=math.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE  is',rmse1)
mae1=mean_absolute_error(y_test, y_pred)
print('MAE is',mae1)

# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse2=relative_root_mean_squared_error(y_test,y_pred)
arrmse2=np.mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small=pd.DataFrame(y_pred)
#df_small = y_test.iloc[:,:3]
features=['Cd',
'Cu',
'Pb',]
correlation_mat = df_small.corr('pearson')
sns.heatmap(correlation_mat, annot = True,yticklabels=features,xticklabels=features)
plt.show()

mean_corr = correlation_mat.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr}")
# Out:
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.3667564901115815
#
# Generation 2 - Current best internal CV score: -0.3667564901115815
#
# Generation 3 - Current best internal CV score: -0.3667564901115815
#
# Generation 4 - Current best internal CV score: -0.36543019213538414
#
# Generation 5 - Current best internal CV score: -0.3651100580091009
#
# Generation 6 - Current best internal CV score: -0.36166224465879465
#
# Generation 7 - Current best internal CV score: -0.36166224465879465
#
# Generation 8 - Current best internal CV score: -0.3534661261530937
#
# Generation 9 - Current best internal CV score: -0.3534661261530937
#
# Generation 10 - Current best internal CV score: -0.3534661261530937
#
# Best pipeline: ExtraTreesRegressor(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), bootstrap=True, max_features=0.4, min_samples_leaf=1, min_samples_split=13, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -277.20278708565655
#
# Generation 2 - Current best internal CV score: -277.20278708565655
#
# Generation 3 - Current best internal CV score: -276.0739386116865
#
# Generation 4 - Current best internal CV score: -276.0739386116865
#
# Generation 5 - Current best internal CV score: -276.0739386116865
#
# Generation 6 - Current best internal CV score: -271.3719617311334
#
# Generation 7 - Current best internal CV score: -271.3719617311334
#
# Generation 8 - Current best internal CV score: -265.2086269627079
#
# Generation 9 - Current best internal CV score: -265.13676252511834
#
# Generation 10 - Current best internal CV score: -265.13676252511834
#
# Best pipeline: ElasticNetCV(SelectPercentile(RobustScaler(GradientBoostingRegressor(input_matrix, alpha=0.8, learning_rate=0.1, loss=huber, max_depth=7, max_features=0.3, min_samples_leaf=2, min_samples_split=14, n_estimators=100, subsample=0.7500000000000001)), percentile=77), l1_ratio=0.8, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -520.1837754613367
#
# Generation 2 - Current best internal CV score: -520.1837754613367
#
# Generation 3 - Current best internal CV score: -520.1837754613367
#
# Generation 4 - Current best internal CV score: -448.88502015664346
#
# Generation 5 - Current best internal CV score: -448.88502015664346
#
# Generation 6 - Current best internal CV score: -448.88502015664346
#
# Generation 7 - Current best internal CV score: -448.88502015664346
#
# Generation 8 - Current best internal CV score: -427.9125518506573
#
# Generation 9 - Current best internal CV score: -427.9125518506573
#
# Generation 10 - Current best internal CV score: -427.9125518506573
#
# Best pipeline: ExtraTreesRegressor(ExtraTreesRegressor(input_matrix, bootstrap=True, max_features=0.45, min_samples_leaf=1, min_samples_split=12, n_estimators=100), bootstrap=False, max_features=0.8500000000000001, min_samples_leaf=2, min_samples_split=10, n_estimators=100)
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# RMSE  is 14.88642193390331
# MAE is 7.852295719085028
# rmse_per_output: [ 0.51484343 11.92855094 22.85303662]
# arrmse = 0.020431698995784214
# Percentage arrmse = 2.04%
# Mean absolute correlation - Dataset 1: 0.6580294999255346

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-jura.csv')
df.head()
y_col = [
'Cd',
'Cu',
'Pb'
]
y = df[y_col]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
X = df[df.columns.drop(y)]
#X=df.drop(columns=['Cd','Cu','Pb'])
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.multioutput import RegressorChain
#reg2 = LinearSVR(epsilon=0.0, tol=0.0001, C=1.0, loss='epsilon_insensitive', fit_intercept=True, intercept_scaling=1.0, dual=True, verbose=2, random_state=None, max_iter=100000000)
reg2 = TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10, scoring='neg_mean_squared_error')

chain = RegressorChain(base_estimator=reg2, order=[0,1,2]).fit(X_train, y_train)
# Create a TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=chain, transformer=target_transformer)
model.fit(X_train, y_train)
y_pred2 = model.predict(X_test)
model.score(X_test, y_test)

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse2=math.sqrt(mean_squared_error(y_test, y_pred2))
print('RMSE  is',rmse2)
mae2=mean_absolute_error(y_test, y_pred2)
print('MAE is',mae2)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse2=relative_root_mean_squared_error(y_test,y_pred2)
arrmse2=np.mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small2=pd.DataFrame(y_pred2)
#df_small = y_test.iloc[:,:3]
features=['Cd',
'Cu',
'Pb',]
correlation_mat2 = df_small2.corr('pearson')
sns.heatmap(correlation_mat2, annot = True,yticklabels=features,xticklabels=features)
plt.show()

mean_corr2 = correlation_mat2.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr2}")
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.3667564901115814
#
# Generation 2 - Current best internal CV score: -0.36662402938574046
#
# Generation 3 - Current best internal CV score: -0.3650029578111325
#
# Generation 4 - Current best internal CV score: -0.35904761234420385
#
# Generation 5 - Current best internal CV score: -0.35904761234420385
#
# Generation 6 - Current best internal CV score: -0.35904761234420385
#
# Generation 7 - Current best internal CV score: -0.3526426683618423
#
# Generation 8 - Current best internal CV score: -0.3526426683618423
#
# Generation 9 - Current best internal CV score: -0.3526426683618423
#
# Generation 10 - Current best internal CV score: -0.3526426683618423
#
# Best pipeline: ElasticNetCV(ExtraTreesRegressor(ExtraTreesRegressor(input_matrix, bootstrap=False, max_features=0.7500000000000001, min_samples_leaf=5, min_samples_split=16, n_estimators=100), bootstrap=False, max_features=0.2, min_samples_leaf=1, min_samples_split=14, n_estimators=100), l1_ratio=0.35000000000000003, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -240.8301465749708
#
# Generation 2 - Current best internal CV score: -240.8301465749708
#
# Generation 3 - Current best internal CV score: -240.8301465749708
#
# Generation 4 - Current best internal CV score: -240.53046124848908
#
# Generation 5 - Current best internal CV score: -240.53046124848908
#
# Generation 6 - Current best internal CV score: -240.49052238538064
#
# Generation 7 - Current best internal CV score: -239.09224637651937
#
# Generation 8 - Current best internal CV score: -239.09224637651937
#
# Generation 9 - Current best internal CV score: -239.09224637651937
#
# Generation 10 - Current best internal CV score: -239.09224637651937
#
# Best pipeline: ElasticNetCV(ExtraTreesRegressor(input_matrix, bootstrap=False, max_features=0.1, min_samples_leaf=18, min_samples_split=8, n_estimators=100), l1_ratio=1.0, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -299.7373283088409
#
# Generation 2 - Current best internal CV score: -299.7373283088409
#
# Generation 3 - Current best internal CV score: -266.7329132236965
#
# Generation 4 - Current best internal CV score: -266.7329132236965
#
# Generation 5 - Current best internal CV score: -266.7329132236965
#
# Generation 6 - Current best internal CV score: -266.7329132236965
#
# Generation 7 - Current best internal CV score: -266.7329132236965
#
# Generation 8 - Current best internal CV score: -266.7329132236965
#
# Generation 9 - Current best internal CV score: -264.6464308966397
#
# Generation 10 - Current best internal CV score: -257.8772584040802
#
# Best pipeline: AdaBoostRegressor(GradientBoostingRegressor(StandardScaler(RidgeCV(input_matrix)), alpha=0.95, learning_rate=0.01, loss=huber, max_depth=1, max_features=0.4, min_samples_leaf=8, min_samples_split=3, n_estimators=100, subsample=0.35000000000000003), learning_rate=0.01, loss=linear, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.015668153099283412
#
# Generation 2 - Current best internal CV score: -0.015618007290600217
#
# Generation 3 - Current best internal CV score: -0.015180277557764544
#
# Generation 4 - Current best internal CV score: -0.014677769704698668
#
# Generation 5 - Current best internal CV score: -0.014674164836579457
#
# Generation 6 - Current best internal CV score: -0.014610215586061561
#
# Generation 7 - Current best internal CV score: -0.014610215586061561
#
# Generation 8 - Current best internal CV score: -0.014363833871483928
#
# Generation 9 - Current best internal CV score: -0.014363833871483928
#
# Generation 10 - Current best internal CV score: -0.014302385935904938
#
# Best pipeline: ElasticNetCV(ExtraTreesRegressor(ExtraTreesRegressor(input_matrix, bootstrap=False, max_features=0.7500000000000001, min_samples_leaf=5, min_samples_split=3, n_estimators=100), bootstrap=False, max_features=1.0, min_samples_leaf=3, min_samples_split=3, n_estimators=100), l1_ratio=0.4, tol=0.001)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.009164713705975094
#
# Generation 2 - Current best internal CV score: -0.009164713705975094
#
# Generation 3 - Current best internal CV score: -0.00913621778202269
#
# Generation 4 - Current best internal CV score: -0.00913621778202269
#
# Generation 5 - Current best internal CV score: -0.009115166752556674
#
# Generation 6 - Current best internal CV score: -0.009112928888709727
#
# Generation 7 - Current best internal CV score: -0.009111738455017261
#
# Generation 8 - Current best internal CV score: -0.009111738455017261
#
# Generation 9 - Current best internal CV score: -0.009002803691323166
#
# Generation 10 - Current best internal CV score: -0.009002803691323166
#
# Best pipeline: ElasticNetCV(FastICA(OneHotEncoder(input_matrix, minimum_fraction=0.1, sparse=False, threshold=10), tol=0.9), l1_ratio=0.65, tol=0.0001)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0037264312259432967
#
# Generation 2 - Current best internal CV score: -0.003664765372375578
#
# Generation 3 - Current best internal CV score: -0.003664765372375578
#
# Generation 4 - Current best internal CV score: -0.003664765372375578
#
# Generation 5 - Current best internal CV score: -0.003664765372375578
#
# Generation 6 - Current best internal CV score: -0.003664765372375578
#
# Generation 7 - Current best internal CV score: -0.003657761911852825
#
# Generation 8 - Current best internal CV score: -0.0036066494205469687
#
# Generation 9 - Current best internal CV score: -0.0033582620649550005
#
# Generation 10 - Current best internal CV score: -0.0028224895357572303
#
# Best pipeline: AdaBoostRegressor(RidgeCV(CombineDFs(input_matrix, Normalizer(RobustScaler(input_matrix), norm=max))), learning_rate=0.5, loss=exponential, n_estimators=100)
# RMSE  is 16.672846199354048
# MAE is 9.234170319052183
# rmse_per_output: [ 0.55573802 12.55775681 25.99894806]
# arrmse = 0.02103793599519549
# Percentage arrmse = 2.10%
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Mean absolute correlation - Dataset 1: 0.7752452507110581

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-jura.csv')
df.head()
y_col = [
'Cd',
'Cu',
'Pb',
# 'Y4',
# 'Y5',
# 'Y6'
]
y = df[y_col]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
X = df[df.columns.drop(y)]
#X=df.drop(columns=['Cd','Cu','Pb'])
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler
from tpot import TPOTRegressor
from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
y_train=scaler.fit_transform(y_train)
y_test=scaler.fit_transform(y_test)

from sklearn.svm import LinearSVR
class MultiOutputTP(object):
  def __init__(self, *args, **kwargs):
    self.args = args
    self.kwargs = kwargs
  def fit(self, X, y):
    X, y = map(np.atleast_2d, (X, y))
    assert X.shape[0] == y.shape[0]
    yy = y.shape[1]
    self.regs = []
    i = 0
    for i in range(yy):

      reg = TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123, n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10,scoring='neg_mean_squared_error')

      Xi = np.column_stack([X, y[:, :i]])
      yi = y[:, i]


      self.regs.append(reg.fit(Xi, yi))
    return self
  def predict(self, X):
    y = np.empty([X.shape[0], len(self.regs)])
    for i, reg in enumerate(self.regs):
      y[:, i] = reg.predict(np.column_stack([X, y[:, :i]]))
    return y

# %%
import numpy as np
from tpot import decorators
#decorators.MAX_EVAL_SECS = 240
reg2 = MultiOutputTP(1).fit(X_train, y_train)
#X = np.dtype('float64')



Ypred2 = reg2.predict(X_test)
from sklearn.metrics import r2_score
r2 = r2_score(y_test, Ypred2)
print('r2 score for perfect model is', r2)

y_test=scaler.inverse_transform(y_test)
Ypred2=scaler.inverse_transform(Ypred2)

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small3=pd.DataFrame(Ypred2)
#df_small = y_test.iloc[:,:3]
features=['Cd',
'Cu',
'Pb']
correlation_mat3 = df_small3.corr('pearson')
sns.heatmap(correlation_mat3, annot = True,yticklabels=features,xticklabels=features)
plt.show()

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse3=math.sqrt(mean_squared_error(y_test, Ypred2))
print('RMSE  is',rmse3)
mae3=mean_absolute_error(y_test, Ypred2)
print('MAE  is',mae3)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, Ypred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)

def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse3=relative_root_mean_squared_error(y_test,Ypred2)
arrmse3=np.mean(rrmse3)
percentage_average_relative_rmse3 = arrmse3 * 100
print("relative_root_mean_squared_error =", rrmse3)
print("arrmse =", arrmse3)
print(f"Percentage arrmse = {percentage_average_relative_rmse3:.2f}%")
mean_corr3 = correlation_mat3.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr3}")
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.015468629027844016
#
# Generation 2 - Current best internal CV score: -0.01519187541138348
#
# Generation 3 - Current best internal CV score: -0.014710198442291994
#
# Generation 4 - Current best internal CV score: -0.01450248126659035
#
# Generation 5 - Current best internal CV score: -0.01450248126659035
#
# Generation 6 - Current best internal CV score: -0.014062665007286096
#
# Generation 7 - Current best internal CV score: -0.014062665007286096
#
# Generation 8 - Current best internal CV score: -0.014062665007286096
#
# Generation 9 - Current best internal CV score: -0.014062665007286096
#
# Generation 10 - Current best internal CV score: -0.013965051353221508
#
# Best pipeline: ExtraTreesRegressor(Normalizer(ElasticNetCV(input_matrix, l1_ratio=0.65, tol=0.001), norm=l1), bootstrap=True, max_features=1.0, min_samples_leaf=2, min_samples_split=8, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.009121411287279094
#
# Generation 2 - Current best internal CV score: -0.009121411287279094
#
# Generation 3 - Current best internal CV score: -0.00911408638728019
#
# Generation 4 - Current best internal CV score: -0.00900571250098605
#
# Generation 5 - Current best internal CV score: -0.00900571250098605
#
# Generation 6 - Current best internal CV score: -0.008992425601336144
#
# Generation 7 - Current best internal CV score: -0.008992425601336144
#
# Generation 8 - Current best internal CV score: -0.008983018612851702
#
# Generation 9 - Current best internal CV score: -0.008896058981769378
#
# Generation 10 - Current best internal CV score: -0.008896058981769378
#
# Best pipeline: RidgeCV(StandardScaler(RBFSampler(SelectPercentile(input_matrix, percentile=48), gamma=0.45)))
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0038342533239735174
#
# Generation 2 - Current best internal CV score: -0.0033516198839063384
#
# Generation 3 - Current best internal CV score: -0.0033516198839063384
#
# Generation 4 - Current best internal CV score: -0.0033516198839063384
#
# Generation 5 - Current best internal CV score: -0.0032209025736779167
#
# Generation 6 - Current best internal CV score: -0.0032209025736779167
#
# Generation 7 - Current best internal CV score: -0.0032209025736779167
#
# Generation 8 - Current best internal CV score: -0.0031405363889309645
#
# Generation 9 - Current best internal CV score: -0.0031405363889309645
#
# Generation 10 - Current best internal CV score: -0.0029731409621133143
#
# Best pipeline: RidgeCV(RandomForestRegressor(PolynomialFeatures(ExtraTreesRegressor(input_matrix, bootstrap=False, max_features=1.0, min_samples_leaf=11, min_samples_split=14, n_estimators=100), degree=2, include_bias=False, interaction_only=False), bootstrap=False, max_features=0.4, min_samples_leaf=6, min_samples_split=3, n_estimators=100))
# r2 score for perfect model is 0.238951993299907
# RMSE  is 20.854034837926633
# MAE  is 10.827665793613383
# rmse_per_output: [ 0.61809048 11.05983747 34.37979445]
# relative_root_mean_squared_error = 0.05213436594093357
# arrmse = 0.05213436594093357
# Percentage arrmse = 5.21%
# Mean absolute correlation - Dataset 1: 0.8151222052400026

# %%
import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat2.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
features=['Cd',
'Cu',
'Pb']
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs Chain_Reg-TPOT")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat2.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))

sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps Chain_Reg-TPOT vs TPOT-MTR")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs TPOT-MTR")
plt.show()



import numpy as np

def fisher_z_transform(corr_matrix):
    return np.arctanh(corr_matrix)  # Equivalent to the formula above

z_A = fisher_z_transform(correlation_mat)
z_B = fisher_z_transform(correlation_mat2)
z_C = fisher_z_transform(correlation_mat3)

from scipy.stats import norm

n1, n2 = len(X), len(X)  # Sample sizes
z_diff_AB = (z_A - z_B) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
p_values_AB = 2 * (1 - norm.cdf(np.abs(z_diff_AB)))

z_diff_BC = (z_B - z_C) / np.sqrt(1 / (n2 - 3) + 1 / (len(X) - 3))
p_values_BC = 2 * (1 - norm.cdf(np.abs(z_diff_BC)))

z_diff_AC = (z_A - z_C) / np.sqrt(1 / (n1 - 3) + 1 / (len(X) - 3))
p_values_AC = 2 * (1 - norm.cdf(np.abs(z_diff_AC)))


import seaborn as sns
import matplotlib.pyplot as plt



significant_diff = (p_values_AB < 0.05).astype(int)
sns.heatmap(significant_diff, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. Chain_Reg-TPOT)')
plt.show()

significant_diff2 = (p_values_BC < 0.05).astype(int)
sns.heatmap(significant_diff2, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (Chain_Reg-TPOT vs. TPOT-MTR)')
plt.show()

significant_diff3 = (p_values_AC < 0.05).astype(int)
sns.heatmap(significant_diff3, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. TPOT-MTR)')
plt.show()
# Out:
# [[           nan 1.50301993e-12 1.67868973e-01]
#  [1.50301993e-12            nan 2.42738204e-01]
#  [1.67868973e-01 2.42738204e-01            nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:6: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:18: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# [[       nan 0.56261732 0.12714636]
#  [0.56261732        nan 0.        ]
#  [0.12714636 0.                nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:43: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:55: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# [[           nan 8.28928037e-11 3.67798166e-03]
#  [8.28928037e-11            nan 0.00000000e+00]
#  [3.67798166e-03 0.00000000e+00            nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:78: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_10040\3521569614.py:90: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\blocks.py:393: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)
