# %%
from tpot import TPOTRegressor
import pandas as pd



import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-andro.csv')
df.head()
y_col = [
'Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6'
# 'Y4',
# 'Y5',
# 'Y6'
]
y = df[y_col]
#x_col_id = ['id']
#x_id = df[x_col_id]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
#X = df[df.columns.drop(y)]
#X=df.drop(columns=['id'])
X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler



from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor
#rfg = MultiOutputRegressor(RandomForestRegressor(n_estimators=100,criterion='squared_error'))
rfg = MultiOutputRegressor(TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10, scoring='neg_mean_squared_error'))
# Create a TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=rfg, transformer=target_transformer)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
model.score(X_test, y_test)




import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse1=math.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE  is',rmse1)
mae1=mean_absolute_error(y_test, y_pred)
print('MAE is',mae1)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse2=relative_root_mean_squared_error(y_test,y_pred)
arrmse2=np.mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small=pd.DataFrame(y_pred)
#df_small = y_test.iloc[:,:3]
features=['Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6']
correlation_mat = df_small.corr('pearson')
sns.heatmap(correlation_mat, annot = True,yticklabels=features,xticklabels=features)
plt.show()

mean_corr = correlation_mat.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr}")
# Out:
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.007627518500832237
#
# Generation 2 - Current best internal CV score: -0.006164829663799146
#
# Generation 3 - Current best internal CV score: -0.006054058402356502
#
# Generation 4 - Current best internal CV score: -0.0033698245660623563
#
# Generation 5 - Current best internal CV score: -0.0033698245660623563
#
# Generation 6 - Current best internal CV score: -0.0033698245660623563
#
# Generation 7 - Current best internal CV score: -0.0033698245660623563
#
# Generation 8 - Current best internal CV score: -0.0029503526838775
#
# Generation 9 - Current best internal CV score: -0.0029503526838775
#
# Generation 10 - Current best internal CV score: -0.0029503526838775
#
# Best pipeline: ExtraTreesRegressor(ZeroCount(input_matrix), bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=3, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0004074829341509737
#
# Generation 2 - Current best internal CV score: -0.00036891359616285184
#
# Generation 3 - Current best internal CV score: -0.00036891359616285184
#
# Generation 4 - Current best internal CV score: -0.00036891359616285184
#
# Generation 5 - Current best internal CV score: -0.0003455447696975691
#
# Generation 6 - Current best internal CV score: -0.0003455447696975691
#
# Generation 7 - Current best internal CV score: -0.0003455447696975691
#
# Generation 8 - Current best internal CV score: -0.0003455447696975691
#
# Generation 9 - Current best internal CV score: -0.0003439107162065292
#
# Generation 10 - Current best internal CV score: -0.0003439107162065292
#
# Best pipeline: DecisionTreeRegressor(input_matrix, max_depth=8, min_samples_leaf=2, min_samples_split=2)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.01569642114993724
#
# Generation 2 - Current best internal CV score: -0.01569642114993724
#
# Generation 3 - Current best internal CV score: -0.013241879094737011
#
# Generation 4 - Current best internal CV score: -0.012895570157235869
#
# Generation 5 - Current best internal CV score: -0.012530736984878383
#
# Generation 6 - Current best internal CV score: -0.011976455349738981
#
# Generation 7 - Current best internal CV score: -0.011976455349738981
#
# Generation 8 - Current best internal CV score: -0.008934545905839426
#
# Generation 9 - Current best internal CV score: -0.008934545905839426
#
# Generation 10 - Current best internal CV score: -0.008126073351363249
#
# Best pipeline: ElasticNetCV(RobustScaler(AdaBoostRegressor(RandomForestRegressor(RandomForestRegressor(input_matrix, bootstrap=True, max_features=0.7000000000000001, min_samples_leaf=13, min_samples_split=14, n_estimators=100), bootstrap=False, max_features=0.8500000000000001, min_samples_leaf=6, min_samples_split=18, n_estimators=100), learning_rate=0.5, loss=linear, n_estimators=100)), l1_ratio=0.15000000000000002, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.01792395263036594
#
# Generation 2 - Current best internal CV score: -0.01764550301463369
#
# Generation 3 - Current best internal CV score: -0.014469187333202205
#
# Generation 4 - Current best internal CV score: -0.014469187333202205
#
# Generation 5 - Current best internal CV score: -0.014384363280360699
#
# Generation 6 - Current best internal CV score: -0.014384363280360699
#
# Generation 7 - Current best internal CV score: -0.014384363280360699
#
# Generation 8 - Current best internal CV score: -0.014384363280360699
#
# Generation 9 - Current best internal CV score: -0.013996801645622073
#
# Generation 10 - Current best internal CV score: -0.01203690329240401
#
# Best pipeline: ExtraTreesRegressor(StandardScaler(RandomForestRegressor(input_matrix, bootstrap=False, max_features=0.3, min_samples_leaf=11, min_samples_split=8, n_estimators=100)), bootstrap=False, max_features=0.7000000000000001, min_samples_leaf=2, min_samples_split=11, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.022721852230625776
#
# Generation 2 - Current best internal CV score: -0.020996114114428557
#
# Generation 3 - Current best internal CV score: -0.01741308789698331
#
# Generation 4 - Current best internal CV score: -0.015512207024214807
#
# Generation 5 - Current best internal CV score: -0.015512207024214807
#
# Generation 6 - Current best internal CV score: -0.015512207024214807
#
# Generation 7 - Current best internal CV score: -0.015512207024214807
#
# Generation 8 - Current best internal CV score: -0.015512207024214807
#
# Generation 9 - Current best internal CV score: -0.015512207024214807
#
# Generation 10 - Current best internal CV score: -0.015512207024214807
#
# Best pipeline: DecisionTreeRegressor(GradientBoostingRegressor(input_matrix, alpha=0.9, learning_rate=1.0, loss=quantile, max_depth=1, max_features=0.6500000000000001, min_samples_leaf=19, min_samples_split=15, n_estimators=100, subsample=0.55), max_depth=6, min_samples_leaf=3, min_samples_split=5)
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.02950419808874849
#
# Generation 2 - Current best internal CV score: -0.0204969025768757
#
# Generation 3 - Current best internal CV score: -0.0204969025768757
#
# Generation 4 - Current best internal CV score: -0.020077544851160863
#
# Generation 5 - Current best internal CV score: -0.020077544851160863
#
# Generation 6 - Current best internal CV score: -0.019709363264042868
#
# Generation 7 - Current best internal CV score: -0.019709363264042868
#
# Generation 8 - Current best internal CV score: -0.018404226353828046
#
# Generation 9 - Current best internal CV score: -0.017012684340616483
#
# Generation 10 - Current best internal CV score: -0.017012684340616483
#
# Best pipeline: KNeighborsRegressor(StandardScaler(RandomForestRegressor(input_matrix, bootstrap=True, max_features=0.25, min_samples_leaf=4, min_samples_split=7, n_estimators=100)), n_neighbors=3, p=2, weights=distance)
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# RMSE  is 12.700780418329481
# MAE is 4.665497228548643
# rmse_per_output: [ 1.09862215  0.04584318  1.3374933   1.13546233 31.02169811  1.1072266 ]
# arrmse = 0.016976078515464857
# Percentage arrmse = 1.70%
# Mean absolute correlation - Dataset 1: 0.5352530587395243

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-andro.csv')
df.head()
y_col = [
'Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6'
# 'Y4',
# 'Y5',
# 'Y6'
]
y = df[y_col]
#x_col_id = ['id']
#x_id = df[x_col_id]
y.head()
#X_col = ['Xloc','Yloc','Cr','Ni','Zn','Co']
#X = df[X_col]
#X = df[df.columns.drop(y)]
#X=df.drop(columns=['id'])
X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))

# Choose a transformer for the target variable (e.g., StandardScaler)
target_transformer = scaler

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.multioutput import RegressorChain
#reg = LinearSVR(epsilon=0.0, tol=0.0001, C=1.0, loss='epsilon_insensitive', fit_intercept=True, intercept_scaling=1.0, dual=True, verbose=2, random_state=None, max_iter=100000000)
reg = TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10, scoring='neg_mean_squared_error')
chain = RegressorChain(base_estimator=reg, order=[0,1,2,3,4,5]).fit(X_train, y_train)
# Create a TransformedTargetRegressor
model = TransformedTargetRegressor(regressor=chain, transformer=target_transformer)
model.fit(X_train, y_train)
y_pred2 = model.predict(X_test)
model.score(X_test, y_test)

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse2=math.sqrt(mean_squared_error(y_test, y_pred2))
print('RMSE  is',rmse2)
mae2=mean_absolute_error(y_test, y_pred2)
print('MAE is',mae2)




# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, y_pred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)


def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse2=relative_root_mean_squared_error(y_test,y_pred2)
arrmse2=np.mean(rrmse2)
percentage_average_relative_rmse2 = arrmse2 * 100
print("arrmse =", arrmse2)
print(f"Percentage arrmse = {percentage_average_relative_rmse2:.2f}%")

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small2=pd.DataFrame(y_pred2)
#df_small = y_test.iloc[:,:3]
features=['Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6']
correlation_mat2 = df_small2.corr('pearson')
sns.heatmap(correlation_mat2, annot = True,yticklabels=features,xticklabels=features)
plt.show()

mean_corr2 = correlation_mat2.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr2}")
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -1.150052908968978
#
# Generation 2 - Current best internal CV score: -1.0355419607287204
#
# Generation 3 - Current best internal CV score: -0.6371294567812499
#
# Generation 4 - Current best internal CV score: -0.6371294567812499
#
# Generation 5 - Current best internal CV score: -0.6371294567812499
#
# Generation 6 - Current best internal CV score: -0.5432041229427098
#
# Generation 7 - Current best internal CV score: -0.5432041229427098
#
# Generation 8 - Current best internal CV score: -0.5432041229427098
#
# Generation 9 - Current best internal CV score: -0.5432041229427098
#
# Generation 10 - Current best internal CV score: -0.5042518049062518
#
# Best pipeline: ExtraTreesRegressor(CombineDFs(GradientBoostingRegressor(input_matrix, alpha=0.85, learning_rate=0.5, loss=huber, max_depth=6, max_features=0.2, min_samples_leaf=17, min_samples_split=10, n_estimators=100, subsample=0.2), input_matrix), bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=3, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0005986139102783408
#
# Generation 2 - Current best internal CV score: -0.0005986139102783408
#
# Generation 3 - Current best internal CV score: -0.0005986139102783408
#
# Generation 4 - Current best internal CV score: -0.0005986139102783408
#
# Generation 5 - Current best internal CV score: -0.0005986139102783408
#
# Generation 6 - Current best internal CV score: -0.0005986139102783408
#
# Generation 7 - Current best internal CV score: -0.0005986139102783408
#
# Generation 8 - Current best internal CV score: -0.0005986139102783408
#
# Generation 9 - Current best internal CV score: -0.0005986139102783408
#
# Generation 10 - Current best internal CV score: -0.0005594534953175154
#
# Best pipeline: AdaBoostRegressor(AdaBoostRegressor(input_matrix, learning_rate=1.0, loss=exponential, n_estimators=100), learning_rate=0.5, loss=square, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -1.0079681526605149
#
# Generation 2 - Current best internal CV score: -1.0079681526605149
#
# Generation 3 - Current best internal CV score: -0.978524108412788
#
# Generation 4 - Current best internal CV score: -0.978524108412788
#
# Generation 5 - Current best internal CV score: -0.9575600223958274
#
# Generation 6 - Current best internal CV score: -0.9575600223958274
#
# Generation 7 - Current best internal CV score: -0.9575600223958274
#
# Generation 8 - Current best internal CV score: -0.901921806480688
#
# Generation 9 - Current best internal CV score: -0.6065182865419907
#
# Generation 10 - Current best internal CV score: -0.6065182865419907
#
# Best pipeline: AdaBoostRegressor(RandomForestRegressor(SGDRegressor(input_matrix, alpha=0.0, eta0=1.0, fit_intercept=False, l1_ratio=0.25, learning_rate=constant, loss=epsilon_insensitive, penalty=elasticnet, power_t=0.1), bootstrap=False, max_features=0.2, min_samples_leaf=4, min_samples_split=9, n_estimators=100), learning_rate=0.01, loss=linear, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.03429513717101172
#
# Generation 2 - Current best internal CV score: -0.03429513717101172
#
# Generation 3 - Current best internal CV score: -0.03429513717101152
#
# Generation 4 - Current best internal CV score: -0.03304989456765957
#
# Generation 5 - Current best internal CV score: -0.03137961852000266
#
# Generation 6 - Current best internal CV score: -0.028839960625969975
#
# Generation 7 - Current best internal CV score: -0.02512436114707702
#
# Generation 8 - Current best internal CV score: -0.02512436114707702
#
# Generation 9 - Current best internal CV score: -0.02512436114707702
#
# Generation 10 - Current best internal CV score: -0.02512436114707702
#
# Best pipeline: ElasticNetCV(MinMaxScaler(SGDRegressor(input_matrix, alpha=0.001, eta0=0.01, fit_intercept=True, l1_ratio=1.0, learning_rate=invscaling, loss=huber, penalty=elasticnet, power_t=0.0)), l1_ratio=0.9500000000000001, tol=0.001)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -114.4008976066599
#
# Generation 2 - Current best internal CV score: -114.4008976066599
#
# Generation 3 - Current best internal CV score: -114.4008976066599
#
# Generation 4 - Current best internal CV score: -114.4008976066599
#
# Generation 5 - Current best internal CV score: -114.4008976066599
#
# Generation 6 - Current best internal CV score: -113.5358186994047
#
# Generation 7 - Current best internal CV score: -98.67397301771872
#
# Generation 8 - Current best internal CV score: -98.67397301771872
#
# Generation 9 - Current best internal CV score: -85.4013857705987
#
# Generation 10 - Current best internal CV score: -85.4013857705987
#
# Best pipeline: AdaBoostRegressor(SelectPercentile(GradientBoostingRegressor(OneHotEncoder(input_matrix, minimum_fraction=0.25, sparse=False, threshold=10), alpha=0.95, learning_rate=0.1, loss=quantile, max_depth=9, max_features=0.9000000000000001, min_samples_leaf=5, min_samples_split=20, n_estimators=100, subsample=0.7500000000000001), percentile=12), learning_rate=0.01, loss=square, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0063243781012900955
#
# Generation 2 - Current best internal CV score: -0.0063243781012900955
#
# Generation 3 - Current best internal CV score: -0.0063243781012900955
#
# Generation 4 - Current best internal CV score: -0.0063243781012900955
#
# Generation 5 - Current best internal CV score: -0.0063243781012900955
#
# Generation 6 - Current best internal CV score: -0.006151424050486756
#
# Generation 7 - Current best internal CV score: -0.006151424050486756
#
# Generation 8 - Current best internal CV score: -0.00607982028784214
#
# Generation 9 - Current best internal CV score: -0.005864334702297908
#
# Generation 10 - Current best internal CV score: -0.005864334702297908
#
# Best pipeline: RidgeCV(SelectPercentile(AdaBoostRegressor(OneHotEncoder(input_matrix, minimum_fraction=0.1, sparse=False, threshold=10), learning_rate=0.001, loss=exponential, n_estimators=100), percentile=92))
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.007627518500832237
#
# Generation 2 - Current best internal CV score: -0.006783110209811437
#
# Generation 3 - Current best internal CV score: -0.006054058402356502
#
# Generation 4 - Current best internal CV score: -0.005861274575862664
#
# Generation 5 - Current best internal CV score: -0.005861274575862664
#
# Generation 6 - Current best internal CV score: -0.005827011421051196
#
# Generation 7 - Current best internal CV score: -0.005522588165513806
#
# Generation 8 - Current best internal CV score: -0.005522588165513806
#
# Generation 9 - Current best internal CV score: -0.005522588165513806
#
# Generation 10 - Current best internal CV score: -0.005522588165513806
#
# Best pipeline: AdaBoostRegressor(CombineDFs(input_matrix, input_matrix), learning_rate=0.5, loss=exponential, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.00025151208971381354
#
# Generation 2 - Current best internal CV score: -0.00025151208971381354
#
# Generation 3 - Current best internal CV score: -0.00025151208971381354
#
# Generation 4 - Current best internal CV score: -0.00025151208971381354
#
# Generation 5 - Current best internal CV score: -0.00025151208971381354
#
# Generation 6 - Current best internal CV score: -0.00023023830569426695
#
# Generation 7 - Current best internal CV score: -0.00023023830569426695
#
# Generation 8 - Current best internal CV score: -0.00023023830569426695
#
# Generation 9 - Current best internal CV score: -0.00023023830569426695
#
# Generation 10 - Current best internal CV score: -0.00023023830569426695
#
# Best pipeline: AdaBoostRegressor(VarianceThreshold(MaxAbsScaler(ZeroCount(input_matrix)), threshold=0.0005), learning_rate=0.1, loss=square, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.01013547946922022
#
# Generation 2 - Current best internal CV score: -0.01013547946922022
#
# Generation 3 - Current best internal CV score: -0.00905057235189082
#
# Generation 4 - Current best internal CV score: -0.00905057235189082
#
# Generation 5 - Current best internal CV score: -0.008461757202614986
#
# Generation 6 - Current best internal CV score: -0.0077504694664214556
#
# Generation 7 - Current best internal CV score: -0.00704284730945502
#
# Generation 8 - Current best internal CV score: -0.00704284730945502
#
# Generation 9 - Current best internal CV score: -0.0069512578749926345
#
# Generation 10 - Current best internal CV score: -0.0069512578749926345
#
# Best pipeline: GradientBoostingRegressor(input_matrix, alpha=0.8, learning_rate=0.1, loss=huber, max_depth=2, max_features=0.35000000000000003, min_samples_leaf=6, min_samples_split=3, n_estimators=100, subsample=1.0)
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0006164212651249651
#
# Generation 2 - Current best internal CV score: -0.00049192072093232
#
# Generation 3 - Current best internal CV score: -0.0004878867620740926
#
# Generation 4 - Current best internal CV score: -0.0004878867620740926
#
# Generation 5 - Current best internal CV score: -0.00048324755564548727
#
# Generation 6 - Current best internal CV score: -0.0004798661689859661
#
# Generation 7 - Current best internal CV score: -0.0004798661689859661
#
# Generation 8 - Current best internal CV score: -0.0004600249740038571
#
# Generation 9 - Current best internal CV score: -0.00046002497400385675
#
# Generation 10 - Current best internal CV score: -0.00046002497400385675
#
# Best pipeline: ElasticNetCV(MinMaxScaler(MinMaxScaler(input_matrix)), l1_ratio=0.8, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.015866737450061372
#
# Generation 2 - Current best internal CV score: -0.015763833464427838
#
# Generation 3 - Current best internal CV score: -0.014123607198745775
#
# Generation 4 - Current best internal CV score: -0.014123607198745775
#
# Generation 5 - Current best internal CV score: -0.014123607198745775
#
# Generation 6 - Current best internal CV score: -0.01290617299232193
#
# Generation 7 - Current best internal CV score: -0.01290617299232193
#
# Generation 8 - Current best internal CV score: -0.01290617299232193
#
# Generation 9 - Current best internal CV score: -0.012900015596426654
#
# Generation 10 - Current best internal CV score: -0.012183264127134373
#
# Best pipeline: AdaBoostRegressor(SelectPercentile(DecisionTreeRegressor(input_matrix, max_depth=10, min_samples_leaf=18, min_samples_split=4), percentile=15), learning_rate=0.001, loss=square, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.0015388294514614193
#
# Generation 2 - Current best internal CV score: -0.00015854349387023052
#
# Generation 3 - Current best internal CV score: -0.00015854349387023052
#
# Generation 4 - Current best internal CV score: -0.00015626636501483128
#
# Generation 5 - Current best internal CV score: -0.00015626636501483128
#
# Generation 6 - Current best internal CV score: -0.00015626636501483128
#
# Generation 7 - Current best internal CV score: -0.00015626636501483128
#
# Generation 8 - Current best internal CV score: -0.00011068969077751502
#
# Generation 9 - Current best internal CV score: -0.00011068969077751502
#
# Generation 10 - Current best internal CV score: -0.00010875525788531927
#
# Best pipeline: ElasticNetCV(RobustScaler(ZeroCount(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False))), l1_ratio=0.7000000000000001, tol=0.001)
# RMSE  is 6.212939744189742
# MAE is 2.6599858629998687
# rmse_per_output: [ 1.43439116  0.03532275  1.16951091  0.74842959 15.05159158  1.03280405]
# arrmse = 0.010305091464479473
# Percentage arrmse = 1.03%
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Mean absolute correlation - Dataset 1: 0.5252216786048322

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Hanafi_Majid\OneDrive - Dell Technologies\Documents\Thesis\datasets\csv_result-andro.csv')
df.head()
y_col = [
'Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6'
# 'Y4',
# 'Y5',
# 'Y6'
]
y = df[y_col]

y.head()

X=df[df.columns.drop(y)]
#X=df.drop(y,x_id)
y.head()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size = 0.20, random_state = 123)
X_train.fillna(X_train.mean(), inplace=True)
X_test.fillna(X_test.mean(), inplace=True)
y_train.fillna(y_train.mean(), inplace=True)
y_test.fillna(y_test.mean(), inplace=True)
from sklearn.preprocessing import MinMaxScaler,StandardScaler

from sklearn.compose import TransformedTargetRegressor

# Initialize the scaler
scaler=MinMaxScaler(feature_range=(0,1))
#scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
#y_train=scaler.fit_transform(y_train)
#y_test=scaler.fit_transform(y_test)


from sklearn.svm import LinearSVR
class MultiOutputTP(object):
  def __init__(self, *args, **kwargs):
    self.args = args
    self.kwargs = kwargs
  def fit(self, X, y):
    X, y = map(np.atleast_2d, (X, y))
    assert X.shape[0] == y.shape[0]
    yy = y.shape[1]
    self.regs = []
    for i in range(yy):
#while i <= Ny:
      reg = TPOTRegressor(generations=10, population_size=50,verbosity=2, random_state=123,n_jobs=-1, max_time_mins=None, max_eval_time_mins=5, cv=10, scoring='neg_mean_squared_error')
      #reg = LinearSVR(epsilon=0.0, tol=0.0001, C=1.0, loss='epsilon_insensitive', fit_intercept=True, intercept_scaling=1.0, dual=True, verbose=1, random_state=123, max_iter=10000)
      Xi = np.hstack([X, y[:, :i]])
      yi = y[:, i]
      self.regs.append(reg.fit(Xi, yi))
    return self
  def predict(self, X):
    y = np.empty([X.shape[0], len(self.regs)])
    for i, reg in enumerate(self.regs):
      y[:, i] = reg.predict(np.hstack([X, y[:, :i]]))
    return y


import numpy as np
from tpot import decorators
decorators.MAX_EVAL_SECS = 240
reg2 = MultiOutputTP(1).fit(X_train, y_train)
#X = np.dtype('float64')



Ypred2 = reg2.predict(X_test)

from sklearn.metrics import r2_score
r2 = r2_score(y_test, Ypred2, multioutput='variance_weighted')
print('r2 score for perfect model is', r2)

from tables import Column
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# taking all rows but only 6 columns
df_small3=pd.DataFrame(Ypred2)
#df_small = y_test.iloc[:,:3]
features=['Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6']
correlation_mat3 = df_small3.corr('pearson')
sns.heatmap(correlation_mat3, annot = True,yticklabels=features,xticklabels=features)
plt.show()

import math
import numpy as np
from statistics import mean
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
rmse3=math.sqrt(mean_squared_error(y_test, Ypred2))
print('RMSE  is',rmse3)
mae3=mean_absolute_error(y_test, Ypred2)
print('MAE  is',mae3)


# Calculate RMSE for each output
rmse_per_output = np.sqrt(mean_squared_error(y_test, Ypred2, multioutput='raw_values'))
print('rmse_per_output:',rmse_per_output)

def relative_root_mean_squared_error(true, pred):
    n = len(true) # update
    num = np.sum(np.square(true - pred)) / n  # update
    den = np.sum(np.square(pred))
    squared_error = num/den
    rrmse_loss = np.sqrt(squared_error)
    return rrmse_loss


rrmse3=relative_root_mean_squared_error(y_test,Ypred2)
arrmse3=np.mean(rrmse3)
percentage_average_relative_rmse3 = arrmse3 * 100
print("relative_root_mean_squared_error =", rrmse3)
print("arrmse =", arrmse3)
print(f"Percentage arrmse = {percentage_average_relative_rmse3:.2f}%")

mean_corr3 = correlation_mat3.abs().mean().mean()
print(f"Mean absolute correlation - Dataset 1: {mean_corr3}")
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -1.0683518788566175
#
# Generation 2 - Current best internal CV score: -0.8708211753607848
#
# Generation 3 - Current best internal CV score: -0.8708211753607848
#
# Generation 4 - Current best internal CV score: -0.8708211753607848
#
# Generation 5 - Current best internal CV score: -0.8023098781080013
#
# Generation 6 - Current best internal CV score: -0.8023098781080013
#
# Generation 7 - Current best internal CV score: -0.8023098781080013
#
# Generation 8 - Current best internal CV score: -0.8023098781080013
#
# Generation 9 - Current best internal CV score: -0.8023098781080013
#
# Generation 10 - Current best internal CV score: -0.7818895064243601
#
# Best pipeline: AdaBoostRegressor(CombineDFs(ExtraTreesRegressor(input_matrix, bootstrap=False, max_features=1.0, min_samples_leaf=11, min_samples_split=2, n_estimators=100), input_matrix), learning_rate=0.01, loss=exponential, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.000609883686477448
#
# Generation 2 - Current best internal CV score: -0.000609883686477448
#
# Generation 3 - Current best internal CV score: -0.00044846483653938316
#
# Generation 4 - Current best internal CV score: -0.00041933667110384293
#
# Generation 5 - Current best internal CV score: -0.00041933667110384293
#
# Generation 6 - Current best internal CV score: -0.000389419003582785
#
# Generation 7 - Current best internal CV score: -0.0003869482265050798
#
# Generation 8 - Current best internal CV score: -0.0003869482265050798
#
# Generation 9 - Current best internal CV score: -0.0003869482265050798
#
# Generation 10 - Current best internal CV score: -0.0003869482265050798
#
# Best pipeline: AdaBoostRegressor(LinearSVR(Nystroem(input_matrix, gamma=1.0, kernel=linear, n_components=7), C=0.001, dual=False, epsilon=0.001, loss=squared_epsilon_insensitive, tol=1e-05), learning_rate=1.0, loss=linear, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -1.09397007794936
#
# Generation 2 - Current best internal CV score: -1.09397007794936
#
# Generation 3 - Current best internal CV score: -1.0471718485302521
#
# Generation 4 - Current best internal CV score: -1.0471718485302521
#
# Generation 5 - Current best internal CV score: -0.8890392227541076
#
# Generation 6 - Current best internal CV score: -0.6368571686415657
#
# Generation 7 - Current best internal CV score: -0.6368571686415657
#
# Generation 8 - Current best internal CV score: -0.6244217989232543
#
# Generation 9 - Current best internal CV score: -0.5745556669363352
#
# Generation 10 - Current best internal CV score: -0.5652879787145577
#
# Best pipeline: AdaBoostRegressor(RidgeCV(RandomForestRegressor(RandomForestRegressor(input_matrix, bootstrap=False, max_features=0.9000000000000001, min_samples_leaf=12, min_samples_split=10, n_estimators=100), bootstrap=False, max_features=0.2, min_samples_leaf=4, min_samples_split=9, n_estimators=100)), learning_rate=0.01, loss=exponential, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.025249510204576674
#
# Generation 2 - Current best internal CV score: -0.0250655225178806
#
# Generation 3 - Current best internal CV score: -0.02468818533598016
#
# Generation 4 - Current best internal CV score: -0.02468818533598016
#
# Generation 5 - Current best internal CV score: -0.02468818533598016
#
# Generation 6 - Current best internal CV score: -0.02468818533598016
#
# Generation 7 - Current best internal CV score: -0.02468818533598016
#
# Generation 8 - Current best internal CV score: -0.02468818533598016
#
# Generation 9 - Current best internal CV score: -0.02468818533598016
#
# Generation 10 - Current best internal CV score: -0.02468818533598016
#
# Best pipeline: ElasticNetCV(input_matrix, l1_ratio=1.0, tol=0.01)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -87.2193920636577
#
# Generation 2 - Current best internal CV score: -87.2193920636577
#
# Generation 3 - Current best internal CV score: -87.2193920636577
#
# Generation 4 - Current best internal CV score: -87.2193920636577
#
# Generation 5 - Current best internal CV score: -87.2193920636577
#
# Generation 6 - Current best internal CV score: -87.2193920636577
#
# Generation 7 - Current best internal CV score: -82.38909575494479
#
# Generation 8 - Current best internal CV score: -82.38909575494479
#
# Generation 9 - Current best internal CV score: -82.38909575494479
#
# Generation 10 - Current best internal CV score: -82.38909575494479
#
# Best pipeline: AdaBoostRegressor(GradientBoostingRegressor(RandomForestRegressor(GradientBoostingRegressor(input_matrix, alpha=0.95, learning_rate=0.1, loss=quantile, max_depth=8, max_features=0.9000000000000001, min_samples_leaf=5, min_samples_split=20, n_estimators=100, subsample=0.7500000000000001), bootstrap=False, max_features=0.1, min_samples_leaf=3, min_samples_split=4, n_estimators=100), alpha=0.95, learning_rate=0.01, loss=quantile, max_depth=8, max_features=0.9000000000000001, min_samples_leaf=5, min_samples_split=20, n_estimators=100, subsample=0.7500000000000001), learning_rate=0.01, loss=square, n_estimators=100)
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
#
# Generation 1 - Current best internal CV score: -0.004300065585772261
#
# Generation 2 - Current best internal CV score: -0.004300065585772261
#
# Generation 3 - Current best internal CV score: -0.004300065585723103
#
# Generation 4 - Current best internal CV score: -0.003773006607495717
#
# Generation 5 - Current best internal CV score: -0.003744301092716306
#
# Generation 6 - Current best internal CV score: -0.003744301092716306
#
# Generation 7 - Current best internal CV score: -0.003744301092716306
#
# Generation 8 - Current best internal CV score: -0.00357348330019941
#
# Generation 9 - Current best internal CV score: -0.00357348330019941
#
# Generation 10 - Current best internal CV score: -0.0035553028791119505
#
# Best pipeline: ElasticNetCV(RidgeCV(Nystroem(input_matrix, gamma=0.65, kernel=linear, n_components=10)), l1_ratio=0.4, tol=0.001)
# r2 score for perfect model is 0.36728544542565605
# RMSE  is 7.555405892692799
# MAE  is 3.3979563398551433
# rmse_per_output: [ 1.10116023  0.48012107  1.9110944   1.33832907 18.2843788   1.14015983]
# relative_root_mean_squared_error = Target      0.003182
# Target_2    0.001387
# Target_3    0.005522
# Target_4    0.003867
# Target_5    0.052831
# Target_6    0.003294
# dtype: float64
# arrmse = 0.011680532687584497
# Percentage arrmse = 1.17%
# Mean absolute correlation - Dataset 1: 0.5114505098696641
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat2.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
features=['Target',
'Target_2',
'Target_3',
'Target_4',
'Target_5',
'Target_6']
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs Chain_Reg-TPOT")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat2.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))

sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps Chain_Reg-TPOT vs TPOT-MTR")
plt.show()



import numpy as np
from scipy.stats import norm

# Fisher z-transform
def fisher_z(r):
    return np.arctanh(r)

# Apply Fisher's z-transform
z1 = fisher_z(correlation_mat.values)  # Convert DataFrame to NumPy array
z2 = fisher_z(correlation_mat3.values)

# Compute z-test statistic for each pair
n1 = len(X) # Number of samples in dataset 1
n2 = len(X)  # Number of samples in dataset 2

# Ensure matching shapes
if z1.shape == z2.shape:
    z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
else:
    raise ValueError("The shapes of correlation matrices do not match!")

from scipy.stats import norm

# Calculate p-values
p_values = 2 * (1 - norm.cdf(abs(z_stat)))
print(p_values)
# Visualize significant differences
plt.figure(figsize=(8, 6))
sns.heatmap(p_values, annot=True, cmap='viridis', vmin=0, vmax=1,yticklabels=features,xticklabels=features)
plt.title("P-Values for Differences Between Correlation Heatmaps MO-TPOT vs TPOT-MTR")
plt.show()



import numpy as np

def fisher_z_transform(corr_matrix):
    return np.arctanh(corr_matrix)  # Equivalent to the formula above

z_A = fisher_z_transform(correlation_mat)
z_B = fisher_z_transform(correlation_mat2)
z_C = fisher_z_transform(correlation_mat3)

from scipy.stats import norm

n1, n2 = len(X), len(X)  # Sample sizes
z_diff_AB = (z_A - z_B) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
p_values_AB = 2 * (1 - norm.cdf(np.abs(z_diff_AB)))

z_diff_BC = (z_B - z_C) / np.sqrt(1 / (n2 - 3) + 1 / (len(X) - 3))
p_values_BC = 2 * (1 - norm.cdf(np.abs(z_diff_BC)))

z_diff_AC = (z_A - z_C) / np.sqrt(1 / (n1 - 3) + 1 / (len(X) - 3))
p_values_AC = 2 * (1 - norm.cdf(np.abs(z_diff_AC)))


import seaborn as sns
import matplotlib.pyplot as plt



significant_diff = (p_values_AB < 0.05).astype(int)
sns.heatmap(significant_diff, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. Chain_Reg-TPOT)')
plt.show()

significant_diff2 = (p_values_BC < 0.05).astype(int)
sns.heatmap(significant_diff2, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (Chain_Reg-TPOT vs. TPOT-MTR)')
plt.show()

significant_diff3 = (p_values_AC < 0.05).astype(int)
sns.heatmap(significant_diff3, annot=True, cmap='Greens', cbar=False,yticklabels=features,xticklabels=features)
plt.title('Statistically Significant Differences (MO-TPOT vs. TPOT-MTR)')
plt.show()
# Out:
# [[           nan 6.54086516e-01 3.09610862e-01 2.04250102e-01
#   1.69965649e-01 1.37203416e-01]
#  [6.54086516e-01            nan 9.08992706e-01 7.72327934e-01
#   6.59266540e-02 2.60624366e-01]
#  [3.09610862e-01 9.08992706e-01            nan 1.28932420e-11
#   1.78485161e-01 4.26309840e-01]
#  [2.04250102e-01 7.72327934e-01 1.28932420e-11            nan
#   2.10795726e-01 3.11871662e-01]
#  [1.69965649e-01 6.59266540e-02 1.78485161e-01 2.10795726e-01
#              nan 3.02091685e-12]
#  [1.37203416e-01 2.60624366e-01 4.26309840e-01 3.11871662e-01
#   3.02091685e-12            nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:6: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:18: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:46: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:58: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# [[       nan 0.93653296 0.90714352 0.99164758 0.79890784 0.71473032]
#  [0.93653296        nan 0.87478907 0.83279751 0.02592684 0.038671  ]
#  [0.90714352 0.87478907        nan 0.34702094 0.0802497  0.05566889]
#  [0.99164758 0.83279751 0.34702094        nan 0.08500791 0.06069118]
#  [0.79890784 0.02592684 0.0802497  0.08500791        nan 0.4000815 ]
#  [0.71473032 0.038671   0.05566889 0.06069118 0.4000815         nan]]
# [[           nan 5.97693271e-01 2.57348154e-01 2.08006061e-01
#   1.03721166e-01 6.40550010e-02]
#  [5.97693271e-01            nan 7.85708507e-01 9.37656097e-01
#   4.77802093e-05 1.41004327e-03]
#  [2.57348154e-01 7.85708507e-01            nan 5.56112534e-09
#   1.97030022e-03 6.74576994e-03]
#  [2.08006061e-01 9.37656097e-01 5.56112534e-09            nan
#   2.94212818e-03 3.88883375e-03]
#  [1.03721166e-01 4.77802093e-05 1.97030022e-03 2.94212818e-03
#              nan 5.32907052e-15]
#  [6.40550010e-02 1.41004327e-03 6.74576994e-03 3.88883375e-03
#   5.32907052e-15            nan]]
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:81: RuntimeWarning: divide by zero encountered in arctanh
#   return np.arctanh(r)
# C:\Users\Hanafi_Majid\AppData\Local\Temp\ipykernel_28072\3870518213.py:93: RuntimeWarning: invalid value encountered in subtract
#   z_stat = (z1 - z2) / np.sqrt(1 / (n1 - 3) + 1 / (n2 - 3))
# C:\Users\Hanafi_Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\blocks.py:393: RuntimeWarning: divide by zero encountered in arctanh
#   result = func(self.values, **kwargs)
